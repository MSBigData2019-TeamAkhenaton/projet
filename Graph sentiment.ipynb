# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfp = pd.read_csv('sentiment.csv', sep=';')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(dfp['fear'], dfp['0'])
plt.xlabel('fear')
plt.ylabel('Hit Power')
# Out:
# Text(0,0.5,'Hit Power')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(dfp['joy'], dfp['0'])
plt.xlabel('Joy')
plt.ylabel('Hit Power')
# Out:
# Text(0,0.5,'Hit Power')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(dfp['sadness'], dfp['0'])
plt.xlabel('Sadness')
plt.ylabel('Hit Power')
# Out:
# Text(0,0.5,'Hit Power')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(dfp['anger'], dfp['0'])
plt.xlabel('Anger')
plt.ylabel('Hit Power')
# Out:
# Text(0,0.5,'Hit Power')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(dfp['disgust'], dfp['0'])
plt.xlabel('Disgust')
plt.ylabel('Hit Power')
# Out:
# Text(0,0.5,'Hit Power')
